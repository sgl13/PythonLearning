# %% [markdown]
# <a href="https://colab.research.google.com/github/sgl13/PythonLearning/blob/main/Day4_Python_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assign the theater ID to a variable
# In the work as an analyst, imagine we are considering sales at a specific theater and we want to save the theater's unique identification, which is "b79cn10k", to a variable. By doing this, we'll be able to access the ID easily if we need it later. In the following code cell:
#
# Assign the theater's unique identification to a variable named theater_id.
#
# Display the contents of the theater_id variable.

# %%
#Activity_Use Python_Syntax
# 1. Assign theater_id
theater_id = "b79cn10k"

# 2. Display contents
print(theater_id)
# Out:
# b79cn10k

# %% [markdown]
# Create a ticket type variable
# As we continue my work, we're provided a list of the different types of tickets sold by the theater: "Senior", "Adult", and "Youth". In this task, focus on the "Adult" ticket type.
#
# Create a variable called ticket_type and assign it a value of "Adult".
# Display the contents of the ticket_type variable.

# %%
# 1. Assign ticket_type
ticket_type = "Adult"

# 2. Display contents
print(ticket_type)
# Out:
# Adult

# %% [markdown]
# Save the number of adult tickets to a variable and check the data type
# Now that we've recorded the types of tickets being sold, it's time to record the number of adult tickets sold so far.
#
# Create a variable called adult_tickets_sold that represents the current number of "adult" tickets sold and assign it a value of 59.0.
#
# Check the data type of adult_tickets_sold.

# %%
# 1. Assign adult_tickets_sold
adult_tickets_sold = 59.0

# 2. Check data type
print(type(adult_tickets_sold))
# Out:
# <class 'float'>

# %% [markdown]
# Convert data types and print the result
# The data you work with as a data professional often needs to be converted to different data types. In this case, the number of tickets sold should be recorded as integers and not floats.
#
# Convert the data saved in the adult_tickets_sold variable from a float to an integer. Reassign the result back to the adult_tickets_sold variable.
#
# Check the data type of adult_tickets_sold

# %%
# 1. Convert float to int
adult_tickets_sold = int(adult_tickets_sold)

# 2. Check data type
print(type(adult_tickets_sold))
# Out:
# <class 'int'>

# %% [markdown]
# **Conclusion**
#
# **Variable Assignment**: Values are assigned to variables using the = operator, which allows data to be stored and accessed easily later in code.
#
# **Inspecting Variables**: The print() function displays the value stored in a variable, while the type() function checks its data type (e.g., str, float, int).
#
# **Type Conversion (Casting)**: Data types can be converted using built-in functions like int() to cast floats to integers, ensuring data is stored in the correct format for analysis.
#
# **Variable Reassignment**: Variables can be updated with new values or new data types by reassigning them back to the same variable name.

# %% [markdown]
# **Functions and conditional statements**

# %% [markdown]
# A **function** allows you to group code together, give it a name, and run it whenever you need it, avoiding repeating code.
#
# **Syntax**: Defined using the def keyword, followed by the function name, parentheses (), and a colon :.
#
# **Parameters**: Optional variables inside the parentheses that accept inputs passed into the function.

# %% [markdown]
# The **return** statement ends the execution of a function and hands back a result to where the function was called.
#
# Without a return statement, a function defaults to returning None.
#
# Returning a value allows you to store the output in a variable or use it in further calculations

# %%
# The print() function can print text to the screen.
print('Black dove, where will you go?')
# Out:
# Black dove, where will you go?

# %%
# The type() function returns an object's data type.
number = 15
type(number)
# Out:
# int

# %%
# The str() function converts an object into a string.
number = str(number)
type(number)
# Out:
# str

# %%
# Define a function.
def greeting(name):
    print('Welcome, ' + name + '!')
    print('You are part of the team!')
greeting('Rebecca')
# Out:
# Welcome, Rebecca!
# You are part of the team!

# %%
# Define a function to calculate the area of a triangle.
def area_triangle(base, height):
    return base * height / 2

# %%
# Use the function to assign new variables and perform calculations.
area_a = area_triangle(5, 4)
area_b = area_triangle(7, 3)
total_area = area_a + area_b
total_area
# Out:
# 20.5

# %%
# Define a function that converts hours, minutes, and seconds to total seconds.
def get_seconds(hours, minutes, seconds):
    total_seconds = 3600*hours + 60*minutes + seconds
    return total_seconds

# %%
# Use the function to return a result.
get_seconds(16, 45, 20)
# Out:
# 60320

# %%
# This code does the same thing for two different people.
name = "Marisol"
number = len(name)*9
print("Hello " + name + ". Your lucky number is " + str(number))

name = "Ardashir"
number = len(name)*9
print("Hello " + name + ". Your lucky number is " + str(number))
# Out:
# Hello Marisol. Your lucky number is 63
# Hello Ardashir. Your lucky number is 72

# %%
# Define a function that simplifies the above code and makes it reusable.
def lucky_number(name):
    number = len(name)*9
    print("Hello " + name + ". Your lucky number is " + str(number))

lucky_number("Marisol")
lucky_number("Ardashir")
# Out:
# Hello Marisol. Your lucky number is 63
# Hello Ardashir. Your lucky number is 72

# %%
# This code requests a number from the user and returns its factorial,
# printing each iteration of the multiplication.
a = input(); y = 1

for i in range(int(a)):
    y = y*(i+1)
    print(y)
# Out:
# 4
# 1
# 2
# 6
# 24

# %%
# This function takes an integer as an input and returns its factorial.
def factorial(n):
    # Exclude 0 as product, start with 1
    y = 1
    for i in range(int(n)):
        y = y*(i+1)
    return y
# Enter a numerical value between 1-9 in the command line that appears.
input_num = input()
# Apply factorial function to an integer input
print(factorial(input_num))
# Out:
# 5
# 120

# %% [markdown]
# **Make comparisons using operators**

# %%
# > checks for greater than
print(10>1)
# Out:
# True

# %%
# == checks for equality
print("cat" == "dog")
# Out:
# False

# %%
# != checks for inequality
print(1 != 2)
# Out:
# True

# %%
# Some operators cannot be used between different data types.
print(1 < "1")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2895/4258758287.py in <cell line: 0>()
#       1 # Some operators cannot be used between different data types.
# ----> 2 print(1 < "1")
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
# Letters that occur earlier in the alphabet evaluate to less than letters from later in the alphabet.
# BOTH sides of an `and` statement must be true to return True.
print("Yellow" > "Cyan" and "Brown" > "Magenta")
# Out:
# False

# %%
# An `or` statement will return True if EITHER side evaluates to True.
print(25 > 50 or 1 != 2)
# Out:
# True

# %%
# `not` reverses Boolean evaluation of what follows it.
print(not 42 == "Answer")
# Out:
# True

# %% [markdown]
# **Use if/elif/else statements to make decisions**

# %%
# Define a function that checks validity of username based on length.
def hint_username(username):
    if len(username) < 8:
        print("Invalid username. Must be at least 8 characters long.")
    else:
        print("Valid username.")

# %%
# Define a function that uses modulo to check if a number is even.
def is_even(number):
    if number % 2 == 0:
        return True
    return False

# %%
is_even(16)
# Out:
# True

# %%
is_even(19)
# Out:
# False

# %%
# Define a function that checks validity of username based on length.
def hint_username(username):
    if len(username) < 8:
        print("Invalid username. Must be at least 8 characters long.")
    elif len(username) > 15:
        print("Invalid username. Cannot exceed 15 characters.")
    else:
        print("Valid username.")

# %%
hint_username("ljñkljfñklasdjflkñadjglk{a")
# Out:
# Invalid username. Cannot exceed 15 characters.

# %%
hint_username("ljñkljfñklas")
# Out:
# Valid username.
