# %% [markdown]
# **Jupyter Notebooks**

# %%
# %pip install numpy pandas matplotlib seaborn
# Out:
# Requirement already satisfied: numpy in /Users/shivakumargl/venv/lib/python3.12/site-packages (2.5.1)
# Collecting pandas
#   Downloading pandas-3.0.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (79 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.11.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (80 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/shivakumargl/venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.28.2 (from matplotlib)
#   Downloading fonttools-4.63.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (118 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.1 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/shivakumargl/venv/lib/python3.12/site-packages (from matplotlib) (26.0)
# Collecting pillow>=9 (from matplotlib)
#   Downloading pillow-12.3.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.1 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in /Users/shivakumargl/venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.5-cp312-cp312-macosx_11_0_arm64.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 24.0 MB/s  0:00:00.1 MB/s eta 0:00:01
# Downloading matplotlib-3.11.1-cp312-cp312-macosx_11_0_arm64.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 24.1 MB/s  0:00:00 26.4 MB/s eta 0:00:01
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading contourpy-1.3.3-cp312-cp312-macosx_11_0_arm64.whl (273 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp312-cp312-macosx_10_13_universal2.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 24.0 MB/s  0:00:00
# Downloading kiwisolver-1.5.0-cp312-cp312-macosx_11_0_arm64.whl (64 kB)
# Downloading pillow-12.3.0-cp312-cp312-macosx_11_0_arm64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 24.1 MB/s  0:00:00
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, pandas, matplotlib, seaborn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [seaborn]━━━ 7/9 [matplotlib]as]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.1 pandas-3.0.5 pillow-12.3.0 pyparsing-3.3.2 seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import statements.
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Create a list.
my_list = [10, 'gold', 'dollars']

# %%
# Use the helper function to calculate F1 score used in the following graphics.
def f1_score(precision, recall):
    score = 2*precision*recall / (precision + recall)
    score = np.nan_to_num(score)

    return score

# %%
# Generate a graph of F1 score for different precision and recall scores.
x = np.linspace(0, 1, 101)
y = np.linspace(0, 1, 101)
X, Y = np.meshgrid(x, y)
Z = f1_score(X, Y)
fig = plt.figure()
fig.set_size_inches(10, 10)
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=2, cstride=3, cmap='plasma')

ax.set_title('$F_{1}$ of precision, recall', size=18)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.view_init(35, -65)

# %% [markdown]
# **Object-oriented programming**

# %%
# Assign a string to a variable and check its type.
magic = 'HOCUS POCUS'
print(type(magic))
# Out:
# <class 'str'>

# %%
# Use the swapcase() string method to convert from caps to lowercase.
magic = 'HOCUS POCUS'
magic = magic.swapcase()
magic
# Out:
# 'hocus pocus'

# %%
# Use the replace() string method to replace some letters with other letters.
magic = magic.replace('cus', 'key')
magic
# Out:
# 'hokey pokey'

# %%
# Use the split() string method to split the string into two strings.
magic = magic.split()
magic
# Out:
# ['hokey', 'pokey']

# %%
# Set up the cell to create the `planets` dataframe.
# (This cell was not shown in the instructional video.)
import pandas as pd
data = [['Mercury', 2440, 0], ['Venus', 6052, 0,], ['Earth', 6371, 1],
        ['Mars', 3390, 2], ['Jupiter', 69911, 80], ['Saturn', 58232, 83],
        ['Uranus', 25362, 27], ['Neptune', 24622, 14]
]

cols = ['Planet', 'radius_km', 'moons']

planets = pd.DataFrame(data, columns=cols)

# %%
# Display the `planets` dataframe.
planets
# Out:
#     Planet  radius_km  moons
# 0  Mercury       2440      0
# 1    Venus       6052      0
# 2    Earth       6371      1
# 3     Mars       3390      2
# 4  Jupiter      69911     80
# 5   Saturn      58232     83
# 6   Uranus      25362     27
# 7  Neptune      24622     14

# %%
# Use the shape dataframe attribute to check the number of rows and columns.
planets.shape
# Out:
# (8, 3)

# %%
# Use the columns dataframe attribute to check column names.
planets.columns
# Out:
# Index(['Planet', 'radius_km', 'moons'], dtype='str')

# %%
planets['Planet']
# Out:
# 0    Mercury
# 1      Venus
# 2      Earth
# 3       Mars
# 4    Jupiter
# 5     Saturn
# 6     Uranus
# 7    Neptune
# Name: Planet, dtype: str

# %%
planets[planets['moons'] > 10]
# Out:
#     Planet  radius_km  moons
# 4  Jupiter      69911     80
# 5   Saturn      58232     83
# 6   Uranus      25362     27
# 7  Neptune      24622     14

# %%
planets.sort_values(by='radius_km', ascending=False)
# Out:
#     Planet  radius_km  moons
# 4  Jupiter      69911     80
# 5   Saturn      58232     83
# 6   Uranus      25362     27
# 7  Neptune      24622     14
# 2    Earth       6371      1
# 1    Venus       6052      0
# 3     Mars       3390      2
# 0  Mercury       2440      0
