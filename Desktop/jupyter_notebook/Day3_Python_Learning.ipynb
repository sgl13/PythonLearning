# %% [markdown]
# **Attributes and methods**
# Python classes are powerful and convenient because they come with built-in features that simplify common data analysis tasks. These features are known as attributes and methods.
#
# Attribute: A value associated with an object or class which is referenced by name using dot notation.
#
# Method: A function that belongs to a class and typically performs an action or operation.
#
# A simpler way of thinking about the distinction between attributes and methods is to remember that attributes are characteristics of the object, while methods are actions or operations.
#
# For example, if the class were Spaceship, then attributes might be:
#
# .name
#
# .kind
#
# .speed
#
# .tractor_beam
#
# .These attributes could be accessed by typing:
#
# .Spaceship.name
#
# .Spaceship.kind
#
# .Spaceship.speed
#
# .Spaceship.tractor_beam
#
# Notice that these characteristics are accessed using only a **dot**.
#
# On the other hand, methods of the Spaceship class might be:
#
# .warp()
#
# .tractor()
#
# **These methods could be used by typing**:
#
# .Spaceship.warp()
#
# .Spaceship.tractor()
#
# **Notice that methods are followed by parentheses, and it’s possible for them to take arguments. For example, Spaceship.warp(7) could change the speed of the ship to warp seven**.

# %% [markdown]
# Defining classes with **unique attributes and methods**
# Python lets you define your own classes, each with their own special attributes and methods. This helps all different kinds of programmers to build reusable code that makes their work more efficient. You can even build the Spaceship class mentioned previously. The example, here, demonstrates how to do thi

# %% [markdown]
# A **class** is like a blueprint for all things that share characteristics and behaviors. In this case, the class is Spaceship. There can be all different kinds of spaceships. They can have different names and different purposes. Whenever we create an object of a given class, we creating an **instance** of that class. This is also known as **instantiating** the class. In the code above, every time you instantiate an object of the Spaceship class it will start with its tractor beam set to off. The tractor beam is a class attribute. All instances of the Spaceship class have one. There are also instance attributes. These are attributes that you can assign when you instantiate the object

# %%
class Spaceship:
    # Class attribute
    tractor_beam = "off"
    speed = 0

    def __init__(self, name, kind):
        # Instance attributes
        self.name = name
        self.kind = kind

    def warp(self, speed):
        """Set the ship's warp speed."""
        self.speed = speed

    def tractor(self):
        """Toggle the tractor beam on/off."""
        if self.tractor_beam == "off":
            self.tractor_beam = "on"
        else:
            self.tractor_beam = "off"

# %% [markdown]
# The next block of code uses the warp() method to set the warp speed to seven. Then it checks the current speed of the ship using the speed attribute.

# %%
# Create an instance of Spaceship
ship = Spaceship("Enterprise", "Explorer")

# Set warp speed
ship.warp(7)

# Check speed
ship.speed
# Out:
# 7

# %% [markdown]
# This final block of code uses the tractor() method to toggle the tractor beam. Then it checks the current status of the tractor beam using the tractor_beam attribute

# %%
# Toggle tractor beam
ship.tractor()

# Check tractor beam status
print(ship.tractor_beam)
# Out:
# on

# %% [markdown]
# **Variables and data types**

# %% [markdown]
# **Rules of variable**
# **Allowed Characters**: Use only letters (a-z, A-Z), numbers (0-9), and underscores (_).
#
# **Starting Character**: Must start with a letter or an underscore (_). Cannot start with a number.
#
# **Case Sensitivity**: Names are case-sensitive (max_age and MAX_AGE are completely different).
#
# **No Keywords**: Cannot use Python reserved words (e.g., if, else, for, class, def).

# %%
# Assign a list containing players' ages.
age_list = [34, 25, 23, 19, 29]

# %%
# Find the maximum age and assign to `max_age` variable.
max_age = max(age_list)
max_age
# Out:
# 34

# %%
# Convert `max_age` to a string.
max_age = str(max_age)
max_age
# Out:
# '34'

# %%
# Reassign the value of `max_age`.
max_age = 'ninety-nine'
max_age
# Out:
# 'ninety-nine'

# %%
# Check the value contained in `max_age` (SHOULD OUTPUT 34).
max_age
# Out:
# 'ninety-nine'

# %%
# Find the minimum age and assign to `min_age` variable.
min_age = min(age_list)

# Subtract `min_age` from `max_age`
max_age - min_age
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       1 # Find the minimum age and assign to `min_age` variable.
#       2 min_age = min(age_list)
#       3
#       4 # Subtract `min_age` from `max_age`
# ----> 5 max_age - min_age
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %% [markdown]
# **Create precise variable names**

# %%
# Trying to assign a value to a reserved keyword will return a syntax error.
else = 'everyone loves some esparagus'
# Out:
#   Cell In[1], line 2
#     else = 'everyone loves some esparagus'
#     ^
# SyntaxError: invalid syntax

# %%
# The word "asparagus" is misspelled. That's allowed.
esparagus = 'everyone loves some esparagus'

# %%
# Order of operations
2 * (3 + 4)
# Out:
# 14

# %%
# Order of operations
(2 * 3) + 4
# Out:
# 10

# %%
# Order of operations
3 + 4 * 10
# Out:
# 43

# %% [markdown]
# **Data types and conversions**

# %%
# Addition of 2 ints
print(7+8)
# Out:
# 15

# %%
# Addition of 2 strings
print("hello " + "world")
# Out:
# hello world

# %%
# You cannot add a string to an integer.
print(7+"8")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # You cannot add a string to an integer.
# ----> 2 print(7+"8")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# The type() function checks the data type of an object.
type("A")
# Out:
# str

# %%
# The type() function checks the data type of an object.
type(2)
# Out:
# int

# %%
# The type() function checks the data type of an object.
type(2.5)
# Out:
# float

# %%
# Implicit conversion
print(1 + 2.5)
# Out:
# 3.5

# %%
# Explicit conversion (The str() function converts a number to a string.)
print("2 + 2 = " + str(2 + 2))
# Out:
# 2 + 2 = 4
