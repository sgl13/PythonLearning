# %% [markdown]
# <a href="https://colab.research.google.com/github/sgl13/PythonLearning/blob/main/Day5_Python_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Analyze a function**
# In we work as a data analyst for a movie theater, we're asked to quickly calculate how much the theater has made in sales so far.
#
# In the following cell, analyze the function named total_sales and make note of our observations.
#
# we do not need to run this cell, but if we do it will not produce an output.

# %%
def total_sales(n):

# %% [markdown]
# **Add a parameter and calculations to the function**
# As we continue refining our code, imagine that the price of tickets is $7.99. Now we will need to add a parameter to the function definition and the calculation to the function body.

# %% [markdown]
# **Add a calculation to the function**
# In this task, update the total_sales function so it returns the value of the number of tickets n multiplied by the price 7.99.

# %%
 def total_sales(n):
    return n * 7.99

# %% [markdown]
# **Call the function**
# With the calculations added to the total_sales function, test it with a value of 59.
#
# Example:
#
# [IN]  total_sales(59)
# [OUT] 471.41

# %%
total_sales(59)
# Out:
# 471.41

# %% [markdown]
# **Create a function that accepts two values**
# we learn that the price of tickets is more expensive for opening night, and now we need to create a function that will accept two values and return their total value.
#
# 3a: Refine the total_sales function
# Update your total_sales function so it accepts two parameters:
#
# price for the price per ticket
# num_tickets for the total number of tickets.
# Return the product of the two arguments. Use the Python round() function to round the returned value to two decimal places.

# %%
def total_sales(price, num_tickets):
    return round(price * num_tickets, 2)

# %% [markdown]
# **Call the function**
# Then, call the function with the value of 15.99 for price and 1001 for the number of tickets sold (num_tickets).
#
# Example:
#
# [IN]  total_sales(15.99, 1001)
# [OUT] 16005.99

# %%
total_sales(15.99, 1001)
# Out:
# 16005.99

# %% [markdown]
# **Test the function with different values**
# As prices and sales fluctate, your function will need to accept different values and still return the total sales.
#
# In this task, practice calling the function with different values.
#
# Example:
#
# [IN]  total_sales(16.99, 1232)
# [OUT] 20931.68
#
# [IN]  total_sales(10.50, 1472)
# [OUT] 15456.0
#
# [IN]  total_sales(5.00, 349)
# [OUT] 1745.0

# %%
# Call total_sales with 16.99 price and 1232 num_tickets
total_sales(16.99, 1232)
# Out:
# 20931.68

# %%
# Call total_sales with 10.50 price and 1472 num_tickets
total_sales(10.50, 1472)
# Out:
# 15456.0

# %%
# Call total_sales with 5.00 price and 349 num_tickets
total_sales(5.00, 349)
# Out:
# 1745.0

# %% [markdown]
# **Conclusion**
#
# [Functions allow us to encapsulate repetitive logic into reusable blocks of code. By using parameters, we can easily calculate total sales dynamically across different ticket prices and quantities without rewriting code. Using built-in functions like round() ensures formatted and accurate financial results]

# %% [markdown]
# **Conditional Statements**

# %% [markdown]
# **Define a comparator function**
# we are a data professional for a movie theater, and your task is to use customers' purchasing data to determine whether or not to send them a marketing email.
#
# Define a function called send_email that accepts the following arguments:
# num_visits - the number of times a customer has visited the theater
# visits_email - the minimum number of visits the customer must have made for them to receive a marketing email
# The function must print either: Send email. or Not enough visits.
# Example:
#
#  [IN] send_email(num_visits=3, visits_email=5)
# [OUT] 'Not enough visits.'
#
#  [IN] send_email(num_visits=5, visits_email=5)
# [OUT] 'Send email.'

# %%
def send_email(num_visits, visits_email):
    if num_visits >= visits_email:
        print("Send email.")
    else:
        print("Not enough visits.")

# %%
send_email(num_visits=3, visits_email=5)
send_email(num_visits=5, visits_email=5)
send_email(num_visits=8, visits_email=5)
# Out:
# Not enough visits.
# Send email.
# Send email.

# %% [markdown]
# **Add logical branching to function**
# The theater is offering a promotion where customers who have visited the theater more than a designated number of times will also receive a coupon with their email. Update the function that you created above to include additional logical branching.
#
# Include an additional argument visits_coupon that represents the minimum number of visits the customer must have made for them to receive a coupon with their email.
#
# The function must print one of three possible messages:
#
# Send email with coupon.
# Send email only.
# Not enough visits.
# The minimum number of visits to receive a coupon will always be greater than the number to receive an email only.
#
# Example:
#
#  [IN] send_email(num_visits=3, visits_email=5, visits_coupon=8)
# [OUT] 'Not enough visits.'
#
#  [IN] send_email(num_visits=5, visits_email=5, visits_coupon=8)
# [OUT] `Send email only.`
#
#  [IN] send_email(num_visits=8, visits_email=5, visits_coupon=8)
# [OUT] `Send email with coupon.`

# %%
def send_email(num_visits, visits_email, visits_coupon):
    if num_visits >= visits_coupon:
        print("Send email with coupon.")
    elif num_visits >= visits_email:
        print("Send email only.")
    else:
        print("Not enough visits.")

# %%
send_email(num_visits=3, visits_email=5, visits_coupon=8)
send_email(num_visits=5, visits_email=5, visits_coupon=8)
send_email(num_visits=6, visits_email=5, visits_coupon=8)
send_email(num_visits=8, visits_email=5, visits_coupon=8)
send_email(num_visits=10, visits_email=5, visits_coupon=8)
# Out:
# Not enough visits.
# Send email only.
# Send email only.
# Send email with coupon.
# Send email with coupon.

# %% [markdown]
# **Conclusion**
# [Conditional statements (if, elif, else) and comparison operators (>=) allow Python to execute specific blocks of code depending on whether conditions are met. Checking the highest threshold (visits_coupon) first ensures that eligibility for both the coupon and the email is properly evaluated before checking lower thresholds.]
